# %%
import pandas as pd

df = pd.DataFrame({
    'Color': 6*['Red'] + 6*['Blue'] + 6*['Purple'], #18
    'Size': 4*['S'] + 8*['M'] + 3*['L'] + 3*[None], #17
    'Gender': 9*['M'] + 9*['F'], #18
    'Price': [*[40*i for i in range(1, 16+1)]] + [1500] + [2000], #18
})
df = df.sample(frac=1).reset_index(drop=True)
df.head(18)
# Out:
#      Color  Size Gender  Price
# 0   Purple     L      F    560
# 1      Red     M      M    240
# 2   Purple     L      F    600
# 3   Purple     L      F    520
# 4     Blue     M      M    360
# 5     Blue     M      F    480
# 6     Blue     M      M    280
# 7      Red     S      M     80
# 8     Blue     M      F    440
# 9      Red     S      M     40
# 10     Red     S      M    120
# 11  Purple  None      F    640
# 12     Red     S      M    160
# 13    Blue     M      M    320
# 14     Red     M      M    200
# 15  Purple  None      F   2000
# 16    Blue     M      F    400
# 17  Purple  None      F   1500

# %% [markdown]
# One-Hot encoding

# %%
df = pd.get_dummies(df, columns=['Color'], prefix='Color')
df.head()
# Out:
#   Size Gender  Price  Color_Blue  Color_Purple  Color_Red
# 0    L      F    560       False          True      False
# 1    M      M    240       False         False       True
# 2    L      F    600       False          True      False
# 3    L      F    520       False          True      False
# 4    M      M    360        True         False      False

# %% [markdown]
# Mapping for binary and ordinal cols

# %%
df['Size'] = df['Size'].map({'S': 0, 'M': 1, 'L': 2})
df['Gender'] = df['Gender'].map({'M': 0, 'F': 1})
df.head()
# Out:
#    Size  Gender  Price  Color_Blue  Color_Purple  Color_Red
# 0   2.0       1    560       False          True      False
# 1   1.0       0    240       False         False       True
# 2   2.0       1    600       False          True      False
# 3   2.0       1    520       False          True      False
# 4   1.0       0    360        True         False      False

# %% [markdown]
# Detect and remove outliers (replaced by a NULL)

# %%
Q1 = df['Price'].quantile(0.25)
Q3 = df['Price'].quantile(0.75)
IQR = Q3 - Q1

LB= Q1 - 1.5 * IQR
UB = Q3 + 1.5 * IQR
print(f'Lower bound: {LB}')
print(f'Upper bound: {UB}')

df['Price'] = df['Price'].apply(lambda x: None if not LB <= x <= UB else x)
df.head(18)
# Out:
# Lower bound: -300.0
# Upper bound: 1060.0
#     Size  Gender  Price  Color_Blue  Color_Purple  Color_Red
# 0    2.0       1  560.0       False          True      False
# 1    1.0       0  240.0       False         False       True
# 2    2.0       1  600.0       False          True      False
# 3    2.0       1  520.0       False          True      False
# 4    1.0       0  360.0        True         False      False
# 5    1.0       1  480.0        True         False      False
# 6    1.0       0  280.0        True         False      False
# 7    0.0       0   80.0       False         False       True
# 8    1.0       1  440.0        True         False      False
# 9    0.0       0   40.0       False         False       True
# 10   0.0       0  120.0       False         False       True
# 11   NaN       1  640.0       False          True      False
# 12   0.0       0  160.0       False         False       True
# 13   1.0       0  320.0        True         False      False
# 14   1.0       0  200.0       False         False       True
# 15   NaN       1    NaN       False          True      False
# 16   1.0       1  400.0        True         False      False
# 17   NaN       1    NaN       False          True      False

# %% [markdown]
# Missing values' filling, via the: {qualitative data -> mode} {quantitative data -> linear interpolation}

# %%
df['Size'].fillna(df['Size'].mode()[0], inplace=True)
df['Price'].interpolate(method='linear', inplace=True)
df.head(18)
# Out:
# C:\Users\Asser\AppData\Local\Temp\ipykernel_18032\3381348345.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Size'].fillna(df['Size'].mode()[0], inplace=True)
# C:\Users\Asser\AppData\Local\Temp\ipykernel_18032\3381348345.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price'].interpolate(method='linear', inplace=True)
#     Size  Gender  Price  Color_Blue  Color_Purple  Color_Red
# 0    2.0       1  560.0       False          True      False
# 1    1.0       0  240.0       False         False       True
# 2    2.0       1  600.0       False          True      False
# 3    2.0       1  520.0       False          True      False
# 4    1.0       0  360.0        True         False      False
# 5    1.0       1  480.0        True         False      False
# 6    1.0       0  280.0        True         False      False
# 7    0.0       0   80.0       False         False       True
# 8    1.0       1  440.0        True         False      False
# 9    0.0       0   40.0       False         False       True
# 10   0.0       0  120.0       False         False       True
# 11   1.0       1  640.0       False          True      False
# 12   0.0       0  160.0       False         False       True
# 13   1.0       0  320.0        True         False      False
# 14   1.0       0  200.0       False         False       True
# 15   1.0       1  300.0       False          True      False
# 16   1.0       1  400.0        True         False      False
# 17   1.0       1  400.0       False          True      False

# %% [markdown]
# Data range normalization [0, 1]

# %%
from sklearn.preprocessing import MinMaxScaler

df[['Price']] = MinMaxScaler().fit_transform(df[['Price']])
df.rename(columns={'Price': 'Pricey-ness'}, inplace=True)
df.head()
# Out:
#    Size  Gender  Pricey-ness  Color_Blue  Color_Purple  Color_Red
# 0   2.0       1     0.866667       False          True      False
# 1   1.0       0     0.333333       False         False       True
# 2   2.0       1     0.933333       False          True      False
# 3   2.0       1     0.800000       False          True      False
# 4   1.0       0     0.533333        True         False      False

# %% [markdown]
# Adding a Class to the data using GMM

# %%
from sklearn.mixture import GaussianMixture
import numpy as np

x = df.copy()
GMM = GaussianMixture(n_components=2, random_state=42)
GMM.fit(x)
labels = GMM.predict(x)
df['Class'] = labels
df.head()
# Out:
#    Size  Gender  Pricey-ness  Color_Blue  Color_Purple  Color_Red  Class
# 0   2.0       1     0.866667       False          True      False      1
# 1   1.0       0     0.333333       False         False       True      0
# 2   2.0       1     0.933333       False          True      False      1
# 3   2.0       1     0.800000       False          True      False      1
# 4   1.0       0     0.533333        True         False      False      0

# %% [markdown]
# Oversampling via SMOTE

# %%
x = df.drop(columns=['Class'])
y = df['Class']
df['Class'].value_counts()
# Out:
# Class
# 0    12
# 1     6
# Name: count, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42)
x, y = smote.fit_resample(x, y)
df['Class'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[140], line 1
# ----> 1 from imblearn.over_sampling import SMOTE
#       3 smote = SMOTE(random_state=42)
#       4 x, y = smote.fit_resample(x, y)
#
# File c:\Users\Asser\Documents\Coding\ML-NTI\Linear-Regression\.venv\Lib\site-packages\imblearn\__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
#      64     from .base import FunctionSampler
#
# File c:\Users\Asser\Documents\Coding\ML-NTI\Linear-Regression\.venv\Lib\site-packages\imblearn\combine\__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File c:\Users\Asser\Documents\Coding\ML-NTI\Linear-Regression\.venv\Lib\site-packages\imblearn\combine\_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File c:\Users\Asser\Documents\Coding\ML-NTI\Linear-Regression\.venv\Lib\site-packages\imblearn\base.py:15
#      12 from sklearn.utils._metadata_requests import METHODS
#      13 from sklearn.utils.multiclass import check_classification_targets
# ---> 15 from .utils import check_sampling_strategy, check_target_type
#      16 from .utils._sklearn_compat import _fit_context, get_tags, validate_data
#      17 from .utils._validation import ArraysTransformer
#
# File c:\Users\Asser\Documents\Coding\ML-NTI\Linear-Regression\.venv\Lib\site-packages\imblearn\utils\__init__.py:6
#       1 """
#       2 The :mod:`imblearn.utils` module includes various utilities.
#       3 """
#       5 from ._docstring import Substitution
# ----> 6 from ._validation import (
#       7     check_neighbors_object,
#       8     check_sampling_strategy,
#       9     check_target_type,
#      10 )
#      12 __all__ = [
#      13     "check_neighbors_object",
#      14     "check_sampling_strategy",
#      15     "check_target_type",
#      16     "Substitution",
#      17 ]
#
# File c:\Users\Asser\Documents\Coding\ML-NTI\Linear-Regression\.venv\Lib\site-packages\imblearn\utils\_validation.py:20
#      17 from sklearn.utils.multiclass import type_of_target
#      18 from sklearn.utils.validation import _num_samples
# ---> 20 from ..utils._sklearn_compat import _is_pandas_df, check_array
#      22 SAMPLING_KIND = (
#      23     "over-sampling",
#      24     "under-sampling",
#    (...)     27     "bypass",
#      28 )
#      29 TARGET_KIND = ("binary", "multiclass", "multilabel-indicator")
#
# File c:\Users\Asser\Documents\Coding\ML-NTI\Linear-Regression\.venv\Lib\site-packages\imblearn\utils\_sklearn_compat.py:815
#     811 @dataclass(**_dataclass_args())
#     812 class Tags(Tags):
#     813     sampler_tags: SamplerTags | None = None
# --> 815 from sklearn.utils._test_common.instance_generator import (
#     816     _construct_instances,  # noqa: F401
#     817 )
#     818 from sklearn.utils.estimator_checks import (
#     819     check_estimator,  # noqa: F401
#     820     parametrize_with_checks,  # noqa: F401
#     821 )
#     822 from sklearn.utils.multiclass import type_of_target  # noqa: F401
#
# File c:\Users\Asser\Documents\Coding\ML-NTI\Linear-Regression\.venv\Lib\site-packages\sklearn\utils\_test_common\instance_generator.py:27
#      12 from sklearn.calibration import CalibratedClassifierCV
#      13 from sklearn.cluster import (
#      14     HDBSCAN,
#      15     AffinityPropagation,
#    (...)     25     SpectralCoclustering,
#      26 )
# ---> 27 from sklearn.compose import ColumnTransformer
#      28 from sklearn.covariance import GraphicalLasso, GraphicalLassoCV
#      29 from sklearn.cross_decomposition import CCA, PLSSVD, PLSCanonical, PLSRegression
#
# File c:\Users\Asser\Documents\Coding\ML-NTI\Linear-Regression\.venv\Lib\site-packages\sklearn\compose\__init__.py:11
#       1 """Meta-estimators for building composite models with transformers.
#       2
#       3 In addition to its current contents, this module will eventually be home to
#       4 refurbished versions of :class:`~sklearn.pipeline.Pipeline` and
#       5 :class:`~sklearn.pipeline.FeatureUnion`.
#       6 """
#       8 # Authors: The scikit-learn developers
#       9 # SPDX-License-Identifier: BSD-3-Clause
# ---> 11 from ._column_transformer import (
#      12     ColumnTransformer,
#      13     make_column_selector,
#      14     make_column_transformer,
#      15 )
#      16 from ._target import TransformedTargetRegressor
#      18 __all__ = [
#      19     "ColumnTransformer",
#      20     "make_column_transformer",
#      21     "TransformedTargetRegressor",
#      22     "make_column_selector",
#      23 ]
#
# File c:\Users\Asser\Documents\Coding\ML-NTI\Linear-Regression\.venv\Lib\site-packages\sklearn\compose\_column_transformer.py:20
#      17 from scipy import sparse
#      19 from ..base import TransformerMixin, _fit_context, clone
# ---> 20 from ..pipeline import _fit_transform_one, _name_estimators, _transform_one
#      21 from ..preprocessing import FunctionTransformer
#      22 from ..utils import Bunch
#
# File c:\Users\Asser\Documents\Coding\ML-NTI\Linear-Regression\.venv\Lib\site-packages\sklearn\pipeline.py:28
#      26 from .utils._tags import get_tags
#      27 from .utils._user_interface import _print_elapsed_time
# ---> 28 from .utils.deprecation import _deprecate_Xt_in_inverse_transform
#      29 from .utils.metadata_routing import (
#      30     MetadataRouter,
#      31     MethodMapping,
#    (...)     35     process_routing,
#      36 )
#      37 from .utils.metaestimators import _BaseComposition, available_if
#
# ImportError: cannot import name '_deprecate_Xt_in_inverse_transform' from 'sklearn.utils.deprecation' (c:\Users\Asser\Documents\Coding\ML-NTI\Linear-Regression\.venv\Lib\site-packages\sklearn\utils\deprecation.py)
